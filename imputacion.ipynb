# %%
from IPython.utils.py3compat import decode
import pandas as pd
data=pd.read_csv('dataset_modficado_imputacoin.csv',encoding='latin-1',delimiter=';')
"""count1 = data['TARIFA'].value_counts().get("BT5B", 0)
count2 = data['TARIFA'].value_counts().get("BT4", 0)
count3 = data['TARIFA'].value_counts().get("BT5A", 0)
count4 = data['TARIFA'].value_counts().get("BT5D", 0)
count5 = data['TARIFA'].value_counts().get("BT6", 0)
count6 = data['TARIFA'].value_counts().get("BT8", 0)
count7 = data['TARIFA'].value_counts().get("MT2", 0)
count8 = data['TARIFA'].value_counts().get("MT3", 0)
count9 = data['TARIFA'].value_counts().get("MT4", 0)

print(f"El número de registros de tipo 'A' es: {count1}\n{count2}\n{count3}\n{count4}\n{count5}\n{count6}\n{count7}\n{count8}\n{count9} ")
"""
# Out:
# 'count1 = data[\'TARIFA\'].value_counts().get("BT5B", 0)\ncount2 = data[\'TARIFA\'].value_counts().get("BT4", 0)\ncount3 = data[\'TARIFA\'].value_counts().get("BT5A", 0)\ncount4 = data[\'TARIFA\'].value_counts().get("BT5D", 0)\ncount5 = data[\'TARIFA\'].value_counts().get("BT6", 0)\ncount6 = data[\'TARIFA\'].value_counts().get("BT8", 0)\ncount7 = data[\'TARIFA\'].value_counts().get("MT2", 0)\ncount8 = data[\'TARIFA\'].value_counts().get("MT3", 0)\ncount9 = data[\'TARIFA\'].value_counts().get("MT4", 0)\n\nprint(f"El número de registros de tipo \'A\' es: {count1}\n{count2}\n{count3}\n{count4}\n{count5}\n{count6}\n{count7}\n{count8}\n{count9} ")\n'

# %%
data
# Out:
#        FECHA_CORTE  PERIODO_FACTURACION                       UUID    UBIGEO  \
# 0       20230608.0             202305.0  C201904291019902323190424  151025.0
# 1       20230608.0             202305.0  C201908191019904549190815  151017.0
# 2       20230608.0             202305.0  C201909281019904871190917  151029.0
# 3       20230608.0             202305.0  C202002061019906396200203  151022.0
# 4       20230608.0             202305.0  C202011060199085730201106  151017.0
# ...            ...                  ...                        ...       ...
# 77626   20230608.0             202305.0  C200507016012600160180828  150721.0
# 77627   20230608.0             202305.0  C200507016012600250180828  150721.0
# 77628   20230608.0             202305.0  C200507016012600267180828  150721.0
# 77629   20230608.0             202305.0  C200507016012600313180828  150721.0
# 77630          NaN                  NaN                        NaN       NaN
#
#       DEPARTAMENTO   PROVINCIA               DISTRITO              LOCALIDAD  \
# 0             LIMA      YAUYOS               QUINOCAY               QUINOCAY
# 1             LIMA      YAUYOS                 HUA¥EC                 HUAÑEC
# 2             LIMA      YAUYOS             TAURIPAMPA             TAURIPAMPA
# 3             LIMA      YAUYOS                   OMAS        ESQUINA DE OMAS
# 4             LIMA      YAUYOS                 HUA¥EC                 HUA¥EC
# ...            ...         ...                    ...                    ...
# 77626         LIMA  HUAROCHIRI  SAN LORENZO DE QUINTI  SAN LORENZO DE QUINTI
# 77627         LIMA  HUAROCHIRI  SAN LORENZO DE QUINTI  SAN LORENZO DE QUINTI
# 77628         LIMA  HUAROCHIRI  SAN LORENZO DE QUINTI  SAN LORENZO DE QUINTI
# 77629         LIMA  HUAROCHIRI  SAN LORENZO DE QUINTI  SAN LORENZO DE QUINTI
# 77630          NaN         NaN                    NaN                    NaN
#
#       TARIFA  FECHA_INICIO  CONSUMO_KW  POTENCIA_CONTRATADA  MONTO_SOLES  \
# 0       BT5B    20190429.0         6.0                  3.0          7.5
# 1       BT5B    20190819.0         0.0                  3.0          6.2
# 2       BT5B    20190928.0         1.0                  3.0          6.4
# 3       BT5B    20200206.0        44.0                  3.0         34.2
# 4       BT5B    20201106.0         0.0                  3.0          6.2
# ...      ...           ...         ...                  ...          ...
# 77626   BT5B    20050701.0        19.0                  1.0         13.5
# 77627   BT5B    20050701.0         6.0                  1.0          8.5
# 77628   BT5B    20050701.0        47.0                  1.0         42.0
# 77629   BT5B    20050701.0         9.0                  1.0          9.7
# 77630    NaN           NaN         NaN                  NaN          NaN
#
#              FASE CODIGO_CIU
# 0      MONOFASICO      T9700
# 1      MONOFASICO      T9700
# 2      MONOFASICO      T9700
# 3      MONOFASICO      T9700
# 4      MONOFASICO      T9700
# ...           ...        ...
# 77626  MONOFASICO      T9700
# 77627  MONOFASICO      T9700
# 77628  MONOFASICO      T9700
# 77629  MONOFASICO      T9700
# 77630         NaN        NaN
#
# [77631 rows x 15 columns]

# %%
print(data.isnull().sum())
# Out:
# FECHA_CORTE             1
# PERIODO_FACTURACION     1
# UUID                    1
# UBIGEO                  1
# DEPARTAMENTO           17
# PROVINCIA               1
# DISTRITO                1
# LOCALIDAD               1
# TARIFA                  1
# FECHA_INICIO            1
# CONSUMO_KW              5
# POTENCIA_CONTRATADA     1
# MONTO_SOLES             7
# FASE                    1
# CODIGO_CIU              6
# dtype: int64

# %%
data=data.drop([77630])
data = data.drop(data[data["DEPARTAMENTO"].isnull()].index)

# %%
print(data.isnull().sum())
# Out:
# FECHA_CORTE            0
# PERIODO_FACTURACION    0
# UUID                   0
# UBIGEO                 0
# DEPARTAMENTO           0
# PROVINCIA              0
# DISTRITO               0
# LOCALIDAD              0
# TARIFA                 0
# FECHA_INICIO           0
# CONSUMO_KW             4
# POTENCIA_CONTRATADA    0
# MONTO_SOLES            6
# FASE                   0
# CODIGO_CIU             5
# dtype: int64

# %%
data=data.dropna()
data
# Out:
#        FECHA_CORTE  PERIODO_FACTURACION                       UUID    UBIGEO  \
# 0       20230608.0             202305.0  C201904291019902323190424  151025.0
# 1       20230608.0             202305.0  C201908191019904549190815  151017.0
# 2       20230608.0             202305.0  C201909281019904871190917  151029.0
# 3       20230608.0             202305.0  C202002061019906396200203  151022.0
# 4       20230608.0             202305.0  C202011060199085730201106  151017.0
# ...            ...                  ...                        ...       ...
# 77625   20230608.0             202305.0  C200507016012600143180828  150721.0
# 77626   20230608.0             202305.0  C200507016012600160180828  150721.0
# 77627   20230608.0             202305.0  C200507016012600250180828  150721.0
# 77628   20230608.0             202305.0  C200507016012600267180828  150721.0
# 77629   20230608.0             202305.0  C200507016012600313180828  150721.0
#
#       DEPARTAMENTO   PROVINCIA               DISTRITO              LOCALIDAD  \
# 0             LIMA      YAUYOS               QUINOCAY               QUINOCAY
# 1             LIMA      YAUYOS                 HUA¥EC                 HUAÑEC
# 2             LIMA      YAUYOS             TAURIPAMPA             TAURIPAMPA
# 3             LIMA      YAUYOS                   OMAS        ESQUINA DE OMAS
# 4             LIMA      YAUYOS                 HUA¥EC                 HUA¥EC
# ...            ...         ...                    ...                    ...
# 77625         LIMA  HUAROCHIRI  SAN LORENZO DE QUINTI  SAN LORENZO DE QUINTI
# 77626         LIMA  HUAROCHIRI  SAN LORENZO DE QUINTI  SAN LORENZO DE QUINTI
# 77627         LIMA  HUAROCHIRI  SAN LORENZO DE QUINTI  SAN LORENZO DE QUINTI
# 77628         LIMA  HUAROCHIRI  SAN LORENZO DE QUINTI  SAN LORENZO DE QUINTI
# 77629         LIMA  HUAROCHIRI  SAN LORENZO DE QUINTI  SAN LORENZO DE QUINTI
#
#       TARIFA  FECHA_INICIO  CONSUMO_KW  POTENCIA_CONTRATADA  MONTO_SOLES  \
# 0       BT5B    20190429.0         6.0                  3.0          7.5
# 1       BT5B    20190819.0         0.0                  3.0          6.2
# 2       BT5B    20190928.0         1.0                  3.0          6.4
# 3       BT5B    20200206.0        44.0                  3.0         34.2
# 4       BT5B    20201106.0         0.0                  3.0          6.2
# ...      ...           ...         ...                  ...          ...
# 77625   BT5B    20050701.0         4.0                  1.0          7.5
# 77626   BT5B    20050701.0        19.0                  1.0         13.5
# 77627   BT5B    20050701.0         6.0                  1.0          8.5
# 77628   BT5B    20050701.0        47.0                  1.0         42.0
# 77629   BT5B    20050701.0         9.0                  1.0          9.7
#
#              FASE CODIGO_CIU
# 0      MONOFASICO      T9700
# 1      MONOFASICO      T9700
# 2      MONOFASICO      T9700
# 3      MONOFASICO      T9700
# 4      MONOFASICO      T9700
# ...           ...        ...
# 77625  MONOFASICO      T9700
# 77626  MONOFASICO      T9700
# 77627  MONOFASICO      T9700
# 77628  MONOFASICO      T9700
# 77629  MONOFASICO      T9700
#
# [77609 rows x 15 columns]

# %%
print(data.isnull().sum())
# Out:
# FECHA_CORTE            0
# PERIODO_FACTURACION    0
# UUID                   0
# UBIGEO                 0
# DEPARTAMENTO           0
# PROVINCIA              0
# DISTRITO               0
# LOCALIDAD              0
# TARIFA                 0
# FECHA_INICIO           0
# CONSUMO_KW             0
# POTENCIA_CONTRATADA    0
# MONTO_SOLES            0
# FASE                   0
# CODIGO_CIU             0
# dtype: int64
